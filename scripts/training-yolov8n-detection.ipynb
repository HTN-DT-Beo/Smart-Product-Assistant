# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
os.environ['PYTHONPATH'] = '/env/python'

# %%
pip install ultralytics -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 36.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 84.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 65.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 38.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 95.2 MB/s eta 0:00:00

# %%
# import os
# import shutil

# src_img = "/content/gdrive/MyDrive/SMART-PRODUCT-ASSISTANT/train/images"
# src_lbl = "/content/gdrive/MyDrive/SMART-PRODUCT-ASSISTANT/train/labels"
# dst_img = "/content/gdrive/MyDrive/SMART-PRODUCT-ASSISTANT/valid/images"
# dst_lbl = "/content/gdrive/MyDrive/SMART-PRODUCT-ASSISTANT/valid/labels"

# # Tạo thư mục đích nếu chưa có
# os.makedirs(dst_img, exist_ok=True)
# os.makedirs(dst_lbl, exist_ok=True)

# # Copy ảnh
# for file_name in os.listdir(src_img):
#     src_file = os.path.join(src_img, file_name)
#     dst_file = os.path.join(dst_img, file_name)
#     shutil.copy2(src_file, dst_file)

# # Copy label
# for file_name in os.listdir(src_lbl):
#     src_file = os.path.join(src_lbl, file_name)
#     dst_file = os.path.join(dst_lbl, file_name)
#     shutil.copy2(src_file, dst_file)

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolov8n.pt")

# Train the model
train_results = model.train(
    data="/content/gdrive/MyDrive/SMART-PRODUCT-ASSISTANT/data.yaml",
    epochs=50,
    imgsz=640,
    batch=16
)


# Evaluate model performance on the validation set
# metrics = model.val()

# Perform object detection on an image
results = model("/content/gdrive/MyDrive/SMART-PRODUCT-ASSISTANT/test_img.jpg")
results[0].show()

# Export the model to ONNX format
path = model.export(format="onnx")  # return path to exported model
# Out:
# Ultralytics 8.3.170 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...
